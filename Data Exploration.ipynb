# %%
# %matplotlib notebook
import pandas as pd
import numpy as np
from sklearn import preprocessing
import matplotlib
import matplotlib.animation
import matplotlib.pyplot as plt

# %%
# Sampling of the first 5 data samples

df1 = pd.read_csv("YearPredictionMSD.csv")
df1.head()
# Out:
#    Year      avg1      avg2      avg3      avg4      avg5      avg6      avg7  \
# 0  2001  49.94357  21.47114  73.07750   8.74861 -17.40628 -13.09905 -25.01202
# 1  2001  48.73215  18.42930  70.32679  12.94636 -10.32437 -24.83777   8.76630
# 2  2001  50.95714  31.85602  55.81851  13.41693  -6.57898 -18.54940  -3.27872
# 3  2001  48.24750  -1.89837  36.29772   2.58776   0.97170 -26.21683   5.05097
# 4  2001  50.97020  42.20998  67.09964   8.46791 -15.85279 -16.81409 -12.48207
#
#        avg8      avg9  ...     var69      var70     var71     var72     var73  \
# 0 -12.23257   7.83089  ...  13.01620  -54.40548  58.99367  15.37344   1.11144
# 1  -0.92019  18.76548  ...   5.66812  -19.68073  33.04964  42.87836  -9.90378
# 2  -2.35035  16.07017  ...   3.03800   26.05866 -50.92779  10.93792  -0.07568
# 3 -10.34124   3.55005  ...  34.57337 -171.70734 -16.96705 -46.67617 -12.51516
# 4  -9.37636  12.63699  ...   9.92661  -55.95724  64.92712 -17.72522  -1.49237
#
# ...

# %%
year = df1['Year']
avg1 = df1['avg1']
avg2 = df1['avg2']
avg3 = df1['avg3']
avg4 = df1['avg4']
avg5 = df1['avg5']
avg6 = df1['avg6']
avg7 = df1['avg7']
avg8 = df1['avg8']
avg9 = df1['avg9']
avg10 = df1['avg10']
avg11 = df1['avg11']
avg12 = df1['avg12']

# %% [markdown]
# # Data Exploration

# %%
fig1 = plt.figure()
ax = fig1.add_subplot(111)
ax.scatter(avg1, year)
plt.xlabel("Average 1")
plt.ylabel("Year")
plt.title("Average of Timbre of 1st Segment vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig2 = plt.figure()
ax = fig2.add_subplot(111)
ax.scatter(avg2, year)
plt.xlabel("Average 2")
plt.ylabel("Year")
plt.title("Average of Timbre of 2nd Segment vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig3 = plt.figure()
ax = fig3.add_subplot(111)
ax.scatter(avg3, year)
plt.xlabel("Average 3")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 3 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig4 = plt.figure()
ax = fig4.add_subplot(111)
ax.scatter(avg4, year)
plt.xlabel("Average 4")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 4 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig5 = plt.figure()
ax = fig5.add_subplot(111)
ax.scatter(avg5, year)
plt.xlabel("Average 5")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 5 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig6 = plt.figure()
ax = fig6.add_subplot(111)
ax.scatter(avg6, year)
plt.xlabel("Average 6")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 6 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig7 = plt.figure()
ax = fig7.add_subplot(111)
ax.scatter(avg7, year)
plt.xlabel("Average 7")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 7 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig8 = plt.figure()
ax = fig8.add_subplot(111)
ax.scatter(avg8, year)
plt.xlabel("Average 8")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 8 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig9 = plt.figure()
ax = fig9.add_subplot(111)
ax.scatter(avg9, year)
plt.xlabel("Average 9")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 9 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig10 = plt.figure()
ax = fig10.add_subplot(111)
ax.scatter(avg10, year)
plt.xlabel("Average 10")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 10 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig11 = plt.figure()
ax = fig11.add_subplot(111)
ax.scatter(avg11, year)
plt.xlabel("Average 11")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 11 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig12 = plt.figure()
ax = fig12.add_subplot(111)
ax.scatter(avg12, year)
plt.xlabel("Average 12")
plt.ylabel("Year")
plt.title("Average of Timbre of Segment 12 vs. Year")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
